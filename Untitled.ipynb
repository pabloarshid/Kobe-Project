# %% [markdown]
# # Since the datset is fairly large you'll see plenty of elipses(...).
# #If that's the case, you can set the following options to expand the data
# #You can adjust these as you'd like
# import pandas as pd
# pd.set_option('display.max_colwidth',250)
# pd.set_option('display.max_rows',250)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import time
import itertools
import operator
import seaborn as sns

# %%
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats, get_team_misc

# %%
Lakers2009 = get_team_stats('LAL', 2009,'PER_GAME')
# Out:
# PER_GAME
# /usr/local/lib/python3.7/dist-packages/basketball_reference_scraper/teams.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s['SEASON'] = f'{season_end_year-1}-{str(season_end_year)[2:]}'

# %%
Lakers2009
# Out:
# G              82
# MP          241.2
# FG           40.3
# FGA          85.1
# FG%         0.474
# 3P            6.7
# 3PA          18.5
# 3P%         0.361
# 2P           33.7
# 2PA          66.6
# 2P%         0.505
# FT           19.6
# FTA          25.5
# FT%          0.77
# ORB          12.4
# DRB          31.5
# TRB          43.9
# AST          23.3
# STL           8.8
# BLK           5.1
# TOV          13.5
# PF           20.7
# PTS         106.9
# TEAM          LAL
# SEASON    2008-09
# dtype: object

# %%
from basketball_reference_scraper.pbp import get_pbp

# %%
df = get_pbp('2020-01-06', 'DEN', 'ATL')

# %%
df
# Out:
#     QUARTER TIME_REMAINING                                      DENVER_ACTION  \
# 0         1        11:40.0                                                NaN
# 1         1        11:23.0  G. Harris misses 2-pt layup from 2 ft (block b...
# 2         1        11:20.0                                                NaN
# 3         1        11:04.0                                                NaN
# 4         1        10:59.0                     Defensive rebound by J. Murray
# ..      ...            ...                                                ...
# 451       4         0:11.0  Personal take foul by V. Carter (drawn by N. J...
# 452       4         0:11.0                  N. Jokić misses free throw 1 of 2
# 453       4         0:11.0                          Offensive rebound by Team
# 454       4         0:11.0                   N. Jokić makes free throw 2 of 2
# 455       4         0:09.0                                                NaN
#
#                                         ATLANTA_ACTION DENVER_SCORE  \
# 0    B. Fernando makes 2-pt layup from 2 ft (assist...            0
# 1                                                  NaN            0
# 2                      Defensive rebound by K. Huerter            0
# 3          K. Huerter misses 3-pt jump shot from 26 ft            0
# 4                                                  NaN            0
# ..                                                 ...          ...
# 451                                                NaN          122
# 452                                                NaN          122
# 453                                                NaN          122
# 454                                                NaN          123
# 455  K. Huerter makes 2-pt dunk from 1 ft (assist b...          123
#
#     ATLANTA_SCORE
# 0               2
# 1               2
# 2               2
# 3               2
# 4               2
# ..            ...
# 451           113
# 452           113
# 453           113
# 454           113
# 455           115
#
# [456 rows x 6 columns]

# %%
from basketball_reference_scraper.shot_charts import get_shot_chart

# %%
d = get_shot_chart('2019-12-28', 'TOR', 'BOS')
# Out:
#           x        y  QUARTER TIME_REMAINING          PLAYER MAKE_MISS  VALUE  \
# 0   23.5 ft  16.3 ft        1        11:24.0     Serge Ibaka      MAKE      2
# 1   27.0 ft  9.75 ft        1        11:03.0     Serge Ibaka      MISS      2
# 2   25.9 ft  4.58 ft        1        10:40.0      OG Anunoby      MAKE      2
# 3   35.3 ft  10.2 ft        1         9:51.0   Patrick McCaw      MAKE      2
# 4   10.8 ft  26.3 ft        1         9:25.0      Kyle Lowry      MAKE      3
# ..      ...      ...      ...            ...             ...       ...    ...
# 79  47.0 ft  9.26 ft        4         3:50.0   Patrick McCaw      MAKE      3
# 80  24.3 ft  5.77 ft        4         2:17.0   Fred VanVleet      MISS      2
# 81  23.2 ft  19.9 ft        4         2:03.0      Kyle Lowry      MAKE      2
# 82  20.4 ft  4.77 ft        4         0:59.0  Oshae Brissett      MISS      2
# 83  21.8 ft  5.27 ft        4         0:23.0   Chris Boucher      MAKE      2
#
#    DISTANCE
# 0     13 ft
# 1      7 ft
# 2      2 ft
# 3     13 ft
# 4     27 ft
# ..      ...
# 79    24 ft
# 80     3 ft
# 81    17 ft
# 82     4 ft
# 83     3 ft
#
# [84 rows x 8 columns]

# %%
d
# Out:
# {'TOR':           x        y  QUARTER TIME_REMAINING          PLAYER MAKE_MISS  VALUE  \
#  0   23.5 ft  16.3 ft        1        11:24.0     Serge Ibaka      MAKE      2
#  1   27.0 ft  9.75 ft        1        11:03.0     Serge Ibaka      MISS      2
#  2   25.9 ft  4.58 ft        1        10:40.0      OG Anunoby      MAKE      2
#  3   35.3 ft  10.2 ft        1         9:51.0   Patrick McCaw      MAKE      2
#  4   10.8 ft  26.3 ft        1         9:25.0      Kyle Lowry      MAKE      3
#  ..      ...      ...      ...            ...             ...       ...    ...
#  79  47.0 ft  9.26 ft        4         3:50.0   Patrick McCaw      MAKE      3
#  80  24.3 ft  5.77 ft        4         2:17.0   Fred VanVleet      MISS      2
#  81  23.2 ft  19.9 ft        4         2:03.0      Kyle Lowry      MAKE      2
#  82  20.4 ft  4.77 ft        4         0:59.0  Oshae Brissett      MISS      2
#  83  21.8 ft  5.27 ft        4         0:23.0   Chris Boucher      MAKE      2
#
#     DISTANCE
#  0     13 ft
#  1      7 ft
#  2      2 ft
#  3     13 ft
#  4     27 ft
#  ..      ...
#  79    24 ft
#  80     3 ft
#  81    17 ft
#  82     4 ft
#  83     3 ft
#
#  [84 rows x 8 columns],
#  'BOS':           x        y  QUARTER TIME_REMAINING          PLAYER MAKE_MISS  VALUE  \
#  0   28.0 ft  5.67 ft        1        11:47.0    Jaylen Brown      MISS      2
#  1   42.0 ft  23.9 ft        1        11:37.0  Gordon Hayward      MISS      3
#  2   23.0 ft  4.08 ft        1        10:56.0    Kemba Walker      MAKE      2
#  3   27.4 ft  3.68 ft        1        10:22.0    Kemba Walker      MISS      2
#  4   19.3 ft  5.97 ft        1        10:09.0    Jaylen Brown      MAKE      2
#  ..      ...      ...      ...            ...             ...       ...    ...
#  73  47.1 ft  7.16 ft        4         2:52.0    Kemba Walker      MISS      3
#  74  25.4 ft  2.88 ft        4         1:53.0    Kemba Walker      MAKE      2
#  75  11.3 ft  25.7 ft        4         1:22.0  Brad Wanamaker      MISS      3
#  76  10.7 ft  26.5 ft        4         0:53.0  Romeo Langford      MISS      3
#  77  28.9 ft  29.1 ft        4         0:14.0  Carsen Edwards      MISS      3
#
#     DISTANCE
#  0      5 ft
#  1     28 ft
#  2      1 ft
#  3      3 ft
#  4      5 ft
#  ..      ...
#  73    24 ft
#  74     1 ft
#  75    26 ft
#  76    27 ft
#  77    27 ft
#
#  [78 rows x 8 columns]}

# %%
sns.set_style("white")
sns.set_color_codes()
plt.figure(figsize=(12,11))
plt.scatter(d['TOR'].x, d['TOR'].y)
plt.show()
